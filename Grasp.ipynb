22,22,22,22,22,22,22,22,22,22,22,22,22,22,22,22,22,21,21,21,21,21,21,21,21,21,21,21,20,20,20,20,20,20,20,20,20,20,20,20]
Num_interacao = 500 # numero maximo de interacoes

def gula(itens):
    caixas = [] # itens dentro da minha caixa
    for item in itens: # andar por todos os itens
        check = False # saber se o item foi ou não colocado em uma caixa ja existente
        for caixa in caixas: # andar por cada caixa
            soma_itens = sum(caixa) # soma o peso de cada item 
            if soma_itens + item <= peso_caixa: # posso colocar esse novo item dentro da minha caixa
                caixa.append(item) # colocando esse item na minha caixa
                check = True # item foi colocado
                break
        if check==False: # criar uma nova caixa para colocar o item
            caixas.append([item])
    return caixas # retorno as coixas que eu montei com os seu pacotes

def busca_local(solucao_gulosa):
    caixas = solucao_gulosa
    check = True
    while check: # o while ira ser executado enquanto ouver uma como distribuir os itens para outras caixas
        check = False
        ale_posi = random.choice(range(len(caixas))) # posicao de alguma caixa
        ale_item = random.choice(caixas[ale_posi]) # algum item da caixa na posicao ale_posi
        for i in range(len(caixas)): # ando por todas a caixas
            soma_itens = sum(caixas[i]) # soma do peso de cada  item 
            # if para chegar se a caixas nao e a caixa aleatoria 
            if i != ale_posi and soma_itens + ale_item <= peso_caixa: # peso da caixa + item que quero adicionar tem que ser menhor ou igual ao peso_caixa
                caixas[i].append(ale_item) # colocando o item aleatorio em uma caixa
                caixas[ale_posi].remove(ale_item) # removendo o item aleatorio da sua caixa de origem
                check = True # item trocado com sucesso
                break
        if len(caixas[ale_posi]) == 0: # se o size da caixa que eu estou tirando os itens for igual a 0 nao ha mais nenhum item nessa caixa
            caixas.pop(ale_posi) # removendo a caixa vazia
            break
    return caixas # retorna os novos arranjos de caixas

def grasp(itens, Num_interacao):
    melhor_caixas = []
    Melhor_solucao = len(itens) # primeira melhor solucao
    for it in range(Num_interacao): # fazer todas as interacoes
        item_aleatorio = random.sample(itens, len(itens)) # embaralho os itens
        solucao_gulosa = gula(item_aleatorio) # solucao gulosa
        BL = busca_local(solucao_gulosa) # montar novos melhores arranjos de caixasa
        if len(BL) < Melhor_solucao: # comparo a solucao BL com a melhor solucao que eu tenho
            Melhor_solucao = len(BL) # faço Melhor_solucao receber a melhor solucao encontrada de caixas
            melhor_caixas = BL
        print(f"It {it+1}/{Num_interacao} - Numero de caixas: {Melhor_solucao}")
    return Melhor_solucao, melhor_caixas # retorno o numero de caixas para empacotar todos os itens

solucao, caixas = grasp(itens, Num_interacao)
print(f"Numero de caixas: {solucao}")
# for i, caixa in enumerate(caixas):
#         print(f"Bin {i + 1}: {caixa}")
# Out:
# It 1/500 - Numero de caixas: 427
# It 2/500 - Numero de caixas: 426
# It 3/500 - Numero de caixas: 426
# It 4/500 - Numero de caixas: 426
# It 5/500 - Numero de caixas: 426
# It 6/500 - Numero de caixas: 426
# It 7/500 - Numero de caixas: 426
# It 8/500 - Numero de caixas: 426
# It 9/500 - Numero de caixas: 425
# It 10/500 - Numero de caixas: 425
# It 11/500 - Numero de caixas: 425
# It 12/500 - Numero de caixas: 425
# It 13/500 - Numero de caixas: 425
# It 14/500 - Numero de caixas: 425
# It 15/500 - Numero de caixas: 425
# It 16/500 - Numero de caixas: 425
# It 17/500 - Numero de caixas: 425
# It 18/500 - Numero de caixas: 425
# It 19/500 - Numero de caixas: 425
# It 20/500 - Numero de caixas: 425
# It 21/500 - Numero de caixas: 425
# It 22/500 - Numero de caixas: 425
# It 23/500 - Numero de caixas: 425
# It 24/500 - Numero de caixas: 425
# It 25/500 - Numero de caixas: 425
# It 26/500 - Numero de caixas: 425
# It 27/500 - Numero de caixas: 425
# It 28/500 - Numero de caixas: 425
# It 29/500 - Numero de caixas: 425
# It 30/500 - Numero de caixas: 425
# It 31/500 - Numero de caixas: 425
# It 32/500 - Numero de caixas: 425
# It 33/500 - Numero de caixas: 425
# It 34/500 - Numero de caixas: 425
# It 35/500 - Numero de caixas: 425
# It 36/500 - Numero de caixas: 425
# It 37/500 - Numero de caixas: 425
# It 38/500 - Numero de caixas: 425
# It 39/500 - Numero de caixas: 425
# It 40/500 - Numero de caixas: 425
# It 41/500 - Numero de caixas: 425
# It 42/500 - Numero de caixas: 425
# It 43/500 - Numero de caixas: 425
# It 44/500 - Numero de caixas: 425
# It 45/500 - Numero de caixas: 425
# It 46/500 - Numero de caixas: 425
# It 47/500 - Numero de caixas: 425
# It 48/500 - Numero de caixas: 425
# It 49/500 - Numero de caixas: 425
# It 50/500 - Numero de caixas: 425
# It 51/500 - Numero de caixas: 425
# It 52/500 - Numero de caixas: 425
# It 53/500 - Numero de caixas: 425
# It 54/500 - Numero de caixas: 425
# It 55/500 - Numero de caixas: 425
# It 56/500 - Numero de caixas: 425
# It 57/500 - Numero de caixas: 425
# It 58/500 - Numero de caixas: 425
# It 59/500 - Numero de caixas: 425
# It 60/500 - Numero de caixas: 425
# It 61/500 - Numero de caixas: 425
# It 62/500 - Numero de caixas: 425
# It 63/500 - Numero de caixas: 425
# It 64/500 - Numero de caixas: 425
# It 65/500 - Numero de caixas: 425
# It 66/500 - Numero de caixas: 425
# It 67/500 - Numero de caixas: 425
# It 68/500 - Numero de caixas: 425
# It 69/500 - Numero de caixas: 425
# It 70/500 - Numero de caixas: 425
# It 71/500 - Numero de caixas: 425
# It 72/500 - Numero de caixas: 425
# It 73/500 - Numero de caixas: 425
# It 74/500 - Numero de caixas: 425
# It 75/500 - Numero de caixas: 425
# It 76/500 - Numero de caixas: 425
# It 77/500 - Numero de caixas: 425
# It 78/500 - Numero de caixas: 425
# It 79/500 - Numero de caixas: 425
# It 80/500 - Numero de caixas: 425
# It 81/500 - Numero de caixas: 425
# It 82/500 - Numero de caixas: 425
# It 83/500 - Numero de caixas: 425
# It 84/500 - Numero de caixas: 425
# It 85/500 - Numero de caixas: 425
# It 86/500 - Numero de caixas: 425
# It 87/500 - Numero de caixas: 425
# It 88/500 - Numero de caixas: 425
# It 89/500 - Numero de caixas: 425
# It 90/500 - Numero de caixas: 425
# It 91/500 - Numero de caixas: 425
# It 92/500 - Numero de caixas: 425
# It 93/500 - Numero de caixas: 425
# It 94/500 - Numero de caixas: 425
# It 95/500 - Numero de caixas: 425
# It 177/500 - Numero de caixas: 425
# It 178/500 - Numero de caixas: 425
# It 179/500 - Numero de caixas: 425
# It 180/500 - Numero de caixas: 425
# It 181/500 - Numero de caixas: 425
# It 182/500 - Numero de caixas: 425
# It 183/500 - Numero de caixas: 425
# It 184/500 - Numero de caixas: 425
# It 185/500 - Numero de caixas: 425
# It 186/500 - Numero de caixas: 425
# It 187/500 - Numero de caixas: 425
# It 188/500 - Numero de caixas: 425
# It 189/500 - Numero de caixas: 425
# It 190/500 - Numero de caixas: 425
# It 191/500 - Numero de caixas: 425
# It 192/500 - Numero de caixas: 425
# It 193/500 - Numero de caixas: 425
# It 194/500 - Numero de caixas: 425
# It 195/500 - Numero de caixas: 425
# It 196/500 - Numero de caixas: 425
# It 197/500 - Numero de caixas: 425
# It 198/500 - Numero de caixas: 425
# It 199/500 - Numero de caixas: 425
# It 200/500 - Numero de caixas: 425
# It 201/500 - Numero de caixas: 425
# It 202/500 - Numero de caixas: 425
# It 203/500 - Numero de caixas: 425
# It 204/500 - Numero de caixas: 425
# It 205/500 - Numero de caixas: 424
# It 206/500 - Numero de caixas: 424
# It 207/500 - Numero de caixas: 424
# It 208/500 - Numero de caixas: 424
# It 209/500 - Numero de caixas: 424
# It 210/500 - Numero de caixas: 424
# It 211/500 - Numero de caixas: 424
# It 212/500 - Numero de caixas: 424
# It 213/500 - Numero de caixas: 424
# It 214/500 - Numero de caixas: 424
# It 215/500 - Numero de caixas: 424
# It 216/500 - Numero de caixas: 424
# It 217/500 - Numero de caixas: 424
# It 218/500 - Numero de caixas: 424
# It 219/500 - Numero de caixas: 424
# It 220/500 - Numero de caixas: 424
# It 221/500 - Numero de caixas: 424
# It 222/500 - Numero de caixas: 424
# It 223/500 - Numero de caixas: 424
# It 224/500 - Numero de caixas: 424
# It 225/500 - Numero de caixas: 424
# It 226/500 - Numero de caixas: 424
# It 227/500 - Numero de caixas: 424
# It 228/500 - Numero de caixas: 424
# It 229/500 - Numero de caixas: 424
# It 230/500 - Numero de caixas: 424
# It 231/500 - Numero de caixas: 424
# It 232/500 - Numero de caixas: 424
# It 233/500 - Numero de caixas: 424
# It 234/500 - Numero de caixas: 424
# It 235/500 - Numero de caixas: 424
# It 236/500 - Numero de caixas: 424
# It 237/500 - Numero de caixas: 424
# It 238/500 - Numero de caixas: 424
# It 239/500 - Numero de caixas: 424
# It 240/500 - Numero de caixas: 424
# It 241/500 - Numero de caixas: 424
# It 242/500 - Numero de caixas: 424
# It 243/500 - Numero de caixas: 424
# It 244/500 - Numero de caixas: 424
# It 245/500 - Numero de caixas: 424
# It 246/500 - Numero de caixas: 424
# It 247/500 - Numero de caixas: 424
# It 248/500 - Numero de caixas: 424
# It 249/500 - Numero de caixas: 424
# It 250/500 - Numero de caixas: 424
# It 251/500 - Numero de caixas: 424
# It 252/500 - Numero de caixas: 424
# It 253/500 - Numero de caixas: 424
# It 254/500 - Numero de caixas: 424
# It 255/500 - Numero de caixas: 424
# It 256/500 - Numero de caixas: 424
# It 257/500 - Numero de caixas: 424
# It 258/500 - Numero de caixas: 424
# It 259/500 - Numero de caixas: 424
# It 260/500 - Numero de caixas: 424
# It 261/500 - Numero de caixas: 424
# It 262/500 - Numero de caixas: 424
# It 263/500 - Numero de caixas: 424
# It 264/500 - Numero de caixas: 424
# It 265/500 - Numero de caixas: 424
# It 266/500 - Numero de caixas: 424
# It 267/500 - Numero de caixas: 424
# It 268/500 - Numero de caixas: 424
# It 269/500 - Numero de caixas: 424
# It 270/500 - Numero de caixas: 424
# It 271/500 - Numero de caixas: 424
# It 272/500 - Numero de caixas: 424
# It 273/500 - Numero de caixas: 424
# It 274/500 - Numero de caixas: 424
# It 275/500 - Numero de caixas: 424
# It 276/500 - Numero de caixas: 424
# It 277/500 - Numero de caixas: 424
# It 278/500 - Numero de caixas: 424
# It 279/500 - Numero de caixas: 424
# It 280/500 - Numero de caixas: 424
# It 281/500 - Numero de caixas: 424
# It 282/500 - Numero de caixas: 424
# It 283/500 - Numero de caixas: 424
# It 284/500 - Numero de caixas: 424
# It 285/500 - Numero de caixas: 424
# It 286/500 - Numero de caixas: 424
# It 287/500 - Numero de caixas: 424
# It 288/500 - Numero de caixas: 424
# It 289/500 - Numero de caixas: 424
# It 290/500 - Numero de caixas: 424
# It 291/500 - Numero de caixas: 424
# It 292/500 - Numero de caixas: 424
# It 293/500 - Numero de caixas: 424
# It 294/500 - Numero de caixas: 424
# It 295/500 - Numero de caixas: 424
# It 296/500 - Numero de caixas: 424
# It 297/500 - Numero de caixas: 424
# It 298/500 - Numero de caixas: 424
# It 299/500 - Numero de caixas: 424
# It 300/500 - Numero de caixas: 424
# It 301/500 - Numero de caixas: 424
# It 302/500 - Numero de caixas: 424
# It 303/500 - Numero de caixas: 424
# It 304/500 - Numero de caixas: 424
# It 305/500 - Numero de caixas: 424
# It 306/500 - Numero de caixas: 424
# It 307/500 - Numero de caixas: 424
# It 308/500 - Numero de caixas: 424
# It 309/500 - Numero de caixas: 424
# It 310/500 - Numero de caixas: 424
# It 311/500 - Numero de caixas: 424
# It 312/500 - Numero de caixas: 424
# It 313/500 - Numero de caixas: 424
# It 314/500 - Numero de caixas: 424
# It 315/500 - Numero de caixas: 424
# It 316/500 - Numero de caixas: 424
# It 317/500 - Numero de caixas: 424
# It 318/500 - Numero de caixas: 424
# It 319/500 - Numero de caixas: 424
# It 320/500 - Numero de caixas: 424
# It 321/500 - Numero de caixas: 424
# It 322/500 - Numero de caixas: 424
# It 323/500 - Numero de caixas: 424
# It 324/500 - Numero de caixas: 424
# It 325/500 - Numero de caixas: 424
# It 326/500 - Numero de caixas: 424
# It 327/500 - Numero de caixas: 424
# It 328/500 - Numero de caixas: 424
# It 329/500 - Numero de caixas: 424
# It 330/500 - Numero de caixas: 424
# It 331/500 - Numero de caixas: 424
# It 332/500 - Numero de caixas: 424
# It 333/500 - Numero de caixas: 424
# It 334/500 - Numero de caixas: 424
# It 335/500 - Numero de caixas: 424
# It 336/500 - Numero de caixas: 424
# It 337/500 - Numero de caixas: 424
# It 338/500 - Numero de caixas: 424
# It 339/500 - Numero de caixas: 424
# It 340/500 - Numero de caixas: 424
# It 341/500 - Numero de caixas: 424
# It 342/500 - Numero de caixas: 424
# It 343/500 - Numero de caixas: 424
# It 344/500 - Numero de caixas: 424
# It 345/500 - Numero de caixas: 424
# It 346/500 - Numero de caixas: 424
# It 347/500 - Numero de caixas: 424
# It 348/500 - Numero de caixas: 424
# It 349/500 - Numero de caixas: 424
# It 350/500 - Numero de caixas: 424
# It 351/500 - Numero de caixas: 424
# It 352/500 - Numero de caixas: 424
# It 353/500 - Numero de caixas: 424
# It 354/500 - Numero de caixas: 424
# It 355/500 - Numero de caixas: 424
# It 356/500 - Numero de caixas: 424
# It 357/500 - Numero de caixas: 424
# It 358/500 - Numero de caixas: 424
# It 359/500 - Numero de caixas: 424
# It 360/500 - Numero de caixas: 424
# It 361/500 - Numero de caixas: 424
# It 362/500 - Numero de caixas: 424
# It 363/500 - Numero de caixas: 424
# It 364/500 - Numero de caixas: 424
# It 365/500 - Numero de caixas: 424
# It 366/500 - Numero de caixas: 424
# It 367/500 - Numero de caixas: 424
# It 368/500 - Numero de caixas: 424
# It 369/500 - Numero de caixas: 424
# It 370/500 - Numero de caixas: 424
# It 371/500 - Numero de caixas: 424
# It 372/500 - Numero de caixas: 424
# It 373/500 - Numero de caixas: 424
# It 374/500 - Numero de caixas: 424
# It 375/500 - Numero de caixas: 424
# It 376/500 - Numero de caixas: 424
# It 377/500 - Numero de caixas: 424
# It 378/500 - Numero de caixas: 424
# It 379/500 - Numero de caixas: 424
# It 380/500 - Numero de caixas: 424
# It 381/500 - Numero de caixas: 424
# It 382/500 - Numero de caixas: 424
# It 383/500 - Numero de caixas: 424
# It 384/500 - Numero de caixas: 424
# It 385/500 - Numero de caixas: 424
# It 386/500 - Numero de caixas: 424
# It 387/500 - Numero de caixas: 424
# It 388/500 - Numero de caixas: 424
# It 389/500 - Numero de caixas: 424
# It 390/500 - Numero de caixas: 424
# It 391/500 - Numero de caixas: 424
# It 392/500 - Numero de caixas: 424
# It 393/500 - Numero de caixas: 424
# It 394/500 - Numero de caixas: 424
# It 395/500 - Numero de caixas: 424
# It 396/500 - Numero de caixas: 424
# It 397/500 - Numero de caixas: 424
# It 398/500 - Numero de caixas: 424
# It 399/500 - Numero de caixas: 424
# It 400/500 - Numero de caixas: 424
# It 401/500 - Numero de caixas: 424
# It 402/500 - Numero de caixas: 424
# It 403/500 - Numero de caixas: 424
# It 404/500 - Numero de caixas: 424
# It 405/500 - Numero de caixas: 424
# It 406/500 - Numero de caixas: 424
# It 407/500 - Numero de caixas: 424
# It 408/500 - Numero de caixas: 424
# It 409/500 - Numero de caixas: 424
# It 410/500 - Numero de caixas: 424
# It 411/500 - Numero de caixas: 424
# It 412/500 - Numero de caixas: 424
# It 413/500 - Numero de caixas: 424
# It 414/500 - Numero de caixas: 424
# It 415/500 - Numero de caixas: 424
# It 416/500 - Numero de caixas: 424
# It 417/500 - Numero de caixas: 424
# It 418/500 - Numero de caixas: 424
# It 419/500 - Numero de caixas: 424
# It 420/500 - Numero de caixas: 424
# It 421/500 - Numero de caixas: 424
# It 422/500 - Numero de caixas: 424
# It 423/500 - Numero de caixas: 424
# It 424/500 - Numero de caixas: 424
# It 425/500 - Numero de caixas: 424
# It 426/500 - Numero de caixas: 424
# It 427/500 - Numero de caixas: 424
# It 428/500 - Numero de caixas: 424
# It 429/500 - Numero de caixas: 424
# It 430/500 - Numero de caixas: 424
# It 431/500 - Numero de caixas: 424
# It 432/500 - Numero de caixas: 424
# It 433/500 - Numero de caixas: 424
# It 434/500 - Numero de caixas: 424
# It 435/500 - Numero de caixas: 424
# It 436/500 - Numero de caixas: 424
# It 437/500 - Numero de caixas: 424
# It 438/500 - Numero de caixas: 424
# It 439/500 - Numero de caixas: 424
# It 440/500 - Numero de caixas: 424
# It 441/500 - Numero de caixas: 424
# It 442/500 - Numero de caixas: 424
# It 443/500 - Numero de caixas: 424
# It 444/500 - Numero de caixas: 424
# It 445/500 - Numero de caixas: 424
# It 446/500 - Numero de caixas: 424
# It 447/500 - Numero de caixas: 424
# It 448/500 - Numero de caixas: 424
# It 449/500 - Numero de caixas: 424
# It 450/500 - Numero de caixas: 424
# It 451/500 - Numero de caixas: 424
# It 452/500 - Numero de caixas: 424
# It 453/500 - Numero de caixas: 424
# It 454/500 - Numero de caixas: 424
# It 455/500 - Numero de caixas: 424
# It 456/500 - Numero de caixas: 424
# It 457/500 - Numero de caixas: 424
# It 458/500 - Numero de caixas: 424
# It 459/500 - Numero de caixas: 424
# It 460/500 - Numero de caixas: 424
# It 461/500 - Numero de caixas: 424
# It 462/500 - Numero de caixas: 424
# It 463/500 - Numero de caixas: 424
# It 464/500 - Numero de caixas: 424
# It 465/500 - Numero de caixas: 424
# It 466/500 - Numero de caixas: 424
# It 467/500 - Numero de caixas: 424
# It 468/500 - Numero de caixas: 424
# It 469/500 - Numero de caixas: 424
# It 470/500 - Numero de caixas: 424
# It 471/500 - Numero de caixas: 424
# It 472/500 - Numero de caixas: 424
# It 473/500 - Numero de caixas: 424
# It 474/500 - Numero de caixas: 424
# It 475/500 - Numero de caixas: 424
# It 476/500 - Numero de caixas: 424
# It 477/500 - Numero de caixas: 424
# It 478/500 - Numero de caixas: 424
# It 479/500 - Numero de caixas: 424
# It 480/500 - Numero de caixas: 424
# It 481/500 - Numero de caixas: 424
# It 482/500 - Numero de caixas: 424
# It 483/500 - Numero de caixas: 424
# It 484/500 - Numero de caixas: 424
# It 485/500 - Numero de caixas: 424
# It 486/500 - Numero de caixas: 424
# It 487/500 - Numero de caixas: 424
# It 488/500 - Numero de caixas: 424
# It 489/500 - Numero de caixas: 424
# It 490/500 - Numero de caixas: 424
# It 491/500 - Numero de caixas: 424
# It 492/500 - Numero de caixas: 424
# It 493/500 - Numero de caixas: 424
# It 494/500 - Numero de caixas: 424
# It 495/500 - Numero de caixas: 424
# It 496/500 - Numero de caixas: 424
# It 497/500 - Numero de caixas: 424
# It 498/500 - Numero de caixas: 424
# It 499/500 - Numero de caixas: 424
# It 500/500 - Numero de caixas: 424
# Numero de caixas: 424
